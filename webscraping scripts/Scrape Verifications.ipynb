# %%
import os
import requests
import time
import pandas as pd
import re
from dotenv import load_dotenv
from fuzzywuzzy import fuzz

# %%
# Load API key from .env
load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_PLACES_API_KEY")
YELP_API_KEY = os.getenv("YELP_API_KEY")

if GOOGLE_API_KEY is None:
    raise ValueError("Google API key not found in the environment")
    
if YELP_API_KEY is None:
    raise ValueError("YELP API key not found in the environment")

# %%
parent_folder = 'webscraping outputs'

files = [
    f'{parent_folder}/Illinois_Adult_Day_Health_Providers.csv',
    f'{parent_folder}/Illinois_Behavior_Intervention_Providers.csv',
    f'{parent_folder}/Illinois_CILA_Providers.csv',
    f'{parent_folder}/Illinois_CLF_Providers.csv',
    f'{parent_folder}/Illinois_Community_Day_Providers.csv',
    f'{parent_folder}/Illinois_Home_Vehicle_Mod_Providers.csv',
    f'{parent_folder}/Illinois_ICF_Providers.csv'
]

# %%
# Read all CSV files with data we need to verify as dataframes, storing them in a single array
dfs = []

for file in files:
    df = pd.read_csv(file)
    dfs.append(df)

# %%
def find_provider_by_address_or_phone_google(address, phone_number):
    base_url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json'
    
    # Search by address
    address_params = {
        'input': address,
        'inputtype': 'textquery',
        'fields': 'place_id,name,formatted_address',
        'key': GOOGLE_API_KEY
    }
    
    address_response = requests.get(base_url, params=address_params).json()
    
    # If a result is found by phone, return it
    if address_response.get('status') == 'OK':
        return address_response

    # If no result is found, search by phone number
    phone_params = {
        'input': phone_number,
        'inputtype': 'phonenumber',
        'fields': 'place_id,name,formatted_phone_number',
        'key': GOOGLE_API_KEY
    }
    phone_response = requests.get(base_url, params=phone_params).json()

    # Return the address response (may also return an empty result)
    return address_response

def find_provider_by_name_google(provider_name):
    base_url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json'
    name_params = {
        'input': provider_name,
        'inputtype': 'textquery',
        'fields': 'place_id,name,formatted_address',
        'key': GOOGLE_API_KEY
    }
    name_response = requests.get(base_url, params=name_params).json()
    return name_response

def find_provider_by_name_yelp(provider_name, location):
    url = "https://api.yelp.com/v3/businesses/search"
    headers = {"Authorization": f"Bearer {YELP_API_KEY}"}
    params = {
        "term": provider_name,
        "location": "Illinois",  # Location string like "City, State"
        "limit": 1  # Adjust as needed
    }

    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        return response.json()  # Returns a dictionary of results
    else:
        print(f"Yelp API Error: {response.status_code} - {response.text}")
        return None

# %%
# Normalize phone numbers
def normalize_phone(phone):
    """Normalize phone numbers by removing non-digit characters."""
    return re.sub(r'\D', '', phone or '')

# Function to compare names with fuzzy matching
def verify_name_match(provider_name, candidate_name, threshold=45):
    if not candidate_name:  # Handle missing candidate_name
        return False
    similarity = fuzz.partial_ratio(provider_name.lower().strip(), candidate_name.lower().strip())
    return similarity >= threshold  # Match if similarity exceeds threshold

# Main function to verify the provider
def verify_provider(provider_name, address, phone_number, city, state):
    # First attempt: Google Places API
    result = find_provider_by_address_or_phone_google(address, phone_number)
    if result and result.get('status') == 'OK':
        candidates = result.get('candidates', [])
        for candidate in candidates:
            candidate_name = candidate.get('name', '').strip()
            candidate_phone = candidate.get('formatted_phone_number', '').strip()

            name_matches = verify_name_match(provider_name, candidate_name)
            phone_matches = normalize_phone(phone_number) == normalize_phone(candidate_phone)

            if name_matches or phone_matches:  # Match found
                return True, candidate

    # Second attempt: Yelp API as fallback
    location = f"{city}, Illinois"
    yelp_result = find_provider_by_name_yelp(provider_name, location)
    if yelp_result:
        for business in yelp_result.get("businesses", []):
            candidate_name = business.get('name', '').strip()
            candidate_phone = business.get('display_phone', '').strip()

            name_matches = verify_name_match(provider_name, candidate_name)
            phone_matches = normalize_phone(phone_number) == normalize_phone(candidate_phone)

            if name_matches or phone_matches:  # Match found
                return True, business  # Return Yelp result if match found

    # No match found in either API
    return False, None

# %%
# Illinois_Adult_Day_Health_Providers
adult_day_health_df = dfs[0][dfs[0]['State'] == 'IL']
adult_day_health_verified_providers = []

for index, row in adult_day_health_df.iterrows():
    # Extract provider details
    provider_name = row['Provider Name']
    provider_address = row['Street Address']
    provider_phone_number = row['Phone Number']
    city = row['City']
    state = row['State']

    print(f"\nProcessing: {provider_name}, {provider_address}, {provider_phone_number}")

    # Verify provider using Google API and fallback to Yelp API
    exists, data = verify_provider(provider_name, provider_address, provider_phone_number, city, state)

    if exists:
        adult_day_health_verified_providers.append({
            'Provider Name': provider_name,
            'Address': provider_address,
            'Phone Number': provider_phone_number,
            'Verified': exists,
            'Matched Data': data  # Store the matched result for debugging
        })
        print(f"✅ Place Verified: {provider_name}")
    else:
        print(f"❌ Place Not Found: {provider_name}")

    # Sleep to respect rate limits
    time.sleep(1)

# Convert results to DataFrame and save to CSV
verified_df = pd.DataFrame(adult_day_health_verified_providers)
verified_df.to_csv('verified providers/Verified_Illinois_Adult_Day_Health_Providers.csv', index=False)

print("\nVerification completed. Results saved to 'Verified_Illinois_Adult_Day_Health_Providers.csv'.")
# Out:
# Processing: ADVOCATE HEALTH AND HOSPITALS, 2025 Windsor Drive, 630-990 5192
# ✅ Place Verified: ADVOCATE HEALTH AND HOSPITALS
#
# Processing: CATHOLIC CHARITIES OF THE ARCHDIOCESE OF CHICAGO, 721 NORTH LASALLE, 312-655-7573
# ✅ Place Verified: CATHOLIC CHARITIES OF THE ARCHDIOCESE OF CHICAGO
#
# Processing: COMMUNITY ADULT DAY CENTER, 4501 MAIN ST, 630-968 1060
# ✅ Place Verified: COMMUNITY ADULT DAY CENTER
#
# Processing: EUROPEAN SERVICES AT HOME, INC, 520 N Hicks Road, 847-202 1249
# ❌ Place Not Found: EUROPEAN SERVICES AT HOME, INC
#
# Processing: HEART TO HEART SERVICES INC, 621 OLD FORGE RD, 708-534 6454
# ✅ Place Verified: HEART TO HEART SERVICES INC
#
# Processing: HUMAN RESOURCES OF EDGAR AND CLARK COUNTIES, PO Box 1118  753 E Court Street, 217-465-4118
# ❌ Place Not Found: HUMAN RESOURCES OF EDGAR AND CLARK COUNTIES
#
# Processing: PRESENCE LIFE CONNECTIONS, 659 E Jefferson Street, 815-232-6181
# ❌ Place Not Found: PRESENCE LIFE CONNECTIONS
#
# Verification completed. Results saved to 'Verified_Illinois_Adult_Day_Health_Providers.csv'.

# %%
# Illinois_Behavior_Intervention_Providers
behavior_intervention_df = dfs[1][dfs[1]['State'] == 'IL']
behavior_intervention_verified_providers = []

for index, row in behavior_intervention_df.iterrows():
    # Extract provider details
    provider_name = row['Provider Name']
    provider_address = row['Street Address']
    provider_phone_number = row['Phone Number']
    city = row['City']
    state = row['State']

    print(f"\nProcessing: {provider_name}, {provider_address}, {provider_phone_number}")

    # Verify provider using Google API and fallback to Yelp API
    exists, data = verify_provider(provider_name, provider_address, provider_phone_number, city, state)

    if exists:
        behavior_intervention_verified_providers.append({
            'Provider Name': provider_name,
            'Address': provider_address,
            'Phone Number': provider_phone_number,
            'Verified': exists,
            'Matched Data': data  # Store the matched result for debugging
        })
        print(f"✅ Place Verified: {provider_name}")
    else:
        print(f"❌ Place Not Found: {provider_name}")

    # Sleep to respect rate limits
    time.sleep(1)

# Convert results to DataFrame and save to CSV
verified_df = pd.DataFrame(behavior_intervention_verified_providers)
verified_df.to_csv('verified providers/Verified_Illinois_Behavior_Intervention_Providers.csv', index=False)

print("\nVerification completed. Results saved to 'Verified_Illinois_Illinois_Behavior_Intervention_Providers.csv'.")
# Out:
# Processing: A PLUS AUTISM SOLUTIONS, 1111 W 14th Place 330, (773) 371-5691
# ❌ Place Not Found: A PLUS AUTISM SOLUTIONS
#
# Processing: A STEP FORWARD INC., 5310 E WILLIAMS ST, (217) 422-6361
# ❌ Place Not Found: A STEP FORWARD INC.
#
# Processing: ABA OF ILLINOIS, LLC, 220 N LAFAYETTE ST, (309) 837-5506
# ❌ Place Not Found: ABA OF ILLINOIS, LLC
#
# Processing: ACE BEHAVIOR SOLUTIONS INC, 13071 DUNMOOR DR, (773) 592-2653
# ❌ Place Not Found: ACE BEHAVIOR SOLUTIONS INC
#
# Processing: ALEXIS LYBROOK TAUBERT PHD LTD, 1001 N MILWAUKEE AVE #304, (773) 248-5135
# ❌ Place Not Found: ALEXIS LYBROOK TAUBERT PHD LTD
#
# Processing: ALSTON, DANA, Not Available, (618) 658-2005
# ❌ Place Not Found: ALSTON, DANA
#
# Processing: APEX PEDIATRIC THERAPY SVCS, 4709 ABBEY LN, (708) 710-0640
# ❌ Place Not Found: APEX PEDIATRIC THERAPY SVCS
#
# Processing: APOSTOLIC CHRISTIAN LIFEPOINTS, INC, 2125 Veterans Road, (309) 266-9781
# ❌ Place Not Found: APOSTOLIC CHRISTIAN LIFEPOINTS, INC
#
# Processing: APPLIED BEHAVIORAL SERVICES LLC, 10 A and K Dr., (618) 524-8996
# ❌ Place Not Found: APPLIED BEHAVIORAL SERVICES LLC
#
# Processing: ARROWLEAF, PO BOX 759 125 NORTH MARKET, (618) 658-2611
# ❌ Place Not Found: ARROWLEAF
#
# Processing: ASPIRE OF ILLINOIS, 1815 SOUTH WOLF ROAD, (708) 236-0979
# ❌ Place Not Found: ASPIRE OF ILLINOIS
#
# Processing: ASSOCIATION FOR INDIVIDUAL DEVELOPMENT, 309 W New Indian Trail Court, (630) 966-4000
# ✅ Place Verified: ASSOCIATION FOR INDIVIDUAL DEVELOPMENT
#
# Processing: AURORA HOME CARE INC., 2970 Maria Ave Suite 210, (847) 559-1222
# ✅ Place Verified: AURORA HOME CARE INC.
#
# Processing: BEHAVIOR ANALYSIS CORPORATION, 109 COUNTRY CLUB EST, (314) 740-5639
# ❌ Place Not Found: BEHAVIOR ANALYSIS CORPORATION
#
# Processing: BEHAVIOR INTERVENTION & ORGANIZATIONAL SYSTEMS LLC dba BIOS ABA Consultants, 828 HANNAH AVE, (708) 257-6074
# ❌ Place Not Found: BEHAVIOR INTERVENTION & ORGANIZATIONAL SYSTEMS LLC dba BIOS ABA Consultants
#
# Processing: BEHAVIORAL LEARNING LLC, 1112 Elgin Ave, (312) 720-9473
# ❌ Place Not Found: BEHAVIORAL LEARNING LLC
#
# Processing: Behavioral Perspective Inc., 245 W ROOSEVELT ROAD BUILDING 15, SUITE 103, (888) 308-3728
# ❌ Place Not Found: Behavioral Perspective Inc.
#
# Processing: BEHAVIORAL SERVICES OF S. IL, 7 BLACKBERRY LN, (618) 303-9282
# ❌ Place Not Found: BEHAVIORAL SERVICES OF S. IL
#
# Processing: BEISNER, TIFFANY, Not Available, (618) 528-0273
# ❌ Place Not Found: BEISNER, TIFFANY
#
# Processing: Best Practices Behavior & Support, 3708 Regal Ridge Circle, (815) 871-9222
# ❌ Place Not Found: Best Practices Behavior & Support
#
# Processing: BETHESDA ABA, 13550 S Route 30 Ste 200, (815) 230-2111
# ❌ Place Not Found: BETHESDA ABA
#
# Processing: BETHSHAN ASSOCIATION, 12927 S MONITOR AVE, (708) 371-0800
# ✅ Place Verified: BETHSHAN ASSOCIATION
#
# Processing: BLUE ISLAND CITIZENS FOR PERSONS WITH DEVELOPMENTAL DISABILITIES, 2155 Broadway, (708) 389-6578
# ❌ Place Not Found: BLUE ISLAND CITIZENS FOR PERSONS WITH DEVELOPMENTAL DISABILITIES
#
# Processing: BROADSTEP ACADEMY-IL INC, 701 W. Lamm Rd., (815) 233-6162
# ❌ Place Not Found: BROADSTEP ACADEMY-IL INC
#
# Processing: BUZELLI, CORTNEY, Not Available, (708) 473-6420
# ❌ Place Not Found: BUZELLI, CORTNEY
#
# Processing: CENTER FOR DISABILITY SERVICES, 311 S Reed Street, (815) 744-3500
# ✅ Place Verified: CENTER FOR DISABILITY SERVICES
#
# Processing: CHALLENGE UNLIMITED INC, 4 EMMIE L KAUS LN, (618) 465-0044
# ✅ Place Verified: CHALLENGE UNLIMITED INC
#
# Processing: Chapman, Terrance, Not Available, (832) 755-5521
# ✅ Place Verified: Chapman, Terrance
#
# Processing: CHICAGO LIGHTHOUSE FOR THE BLIND, 1850 W ROOSEVELT RD, (312) 666-1331
# ✅ Place Verified: CHICAGO LIGHTHOUSE FOR THE BLIND
#
# Processing: CILA CORPORATION, 832-C W NORTH AVE P.O. BOX 160, (618) 662-8494
# ❌ Place Not Found: CILA CORPORATION
#
# Processing: CLEARBROOK, 1835 WEST CENTRAL ROAD, (847) 870-7711
# ✅ Place Verified: CLEARBROOK
#
# Processing: COLEMAN TRI COUNTY SERVICES, PO BOX 869 - 22 Veterans Drive, (618) 252-0275
# ✅ Place Verified: COLEMAN TRI COUNTY SERVICES
#
# Processing: COMMUNITY LINK INC, 1665 N 4TH ST, PO BOX 157, (618) 526-8800
# ❌ Place Not Found: COMMUNITY LINK INC
#
# Processing: COMMUNITY SUPPORT SERVICES INC, 9021 OGDEN AVE, (708) 354-4547
# ❌ Place Not Found: COMMUNITY SUPPORT SERVICES INC
#
# Processing: CONSULTING PROFESSIONALS INC, 6300 N RIDGE, (773) 973-6300
# ✅ Place Verified: CONSULTING PROFESSIONALS INC
#
# Processing: COPING TOGETHER SERVICES INC, 15127 S 73RD AVE STE C, (708) 586-9303
# ❌ Place Not Found: COPING TOGETHER SERVICES INC
#
# Processing: CORNERSTONE SERVICES, 777 JOYCE RD, (815) 727-6666
# ✅ Place Verified: CORNERSTONE SERVICES
#
# Processing: COUNSELING SPECIAL NEEDS ADULTS, 610 Academy Dr, (847) 205-1234
# ❌ Place Not Found: COUNSELING SPECIAL NEEDS ADULTS
#
# Processing: CTF ILLLINOIS, 18230 Orland Parkway, (708) 429-1260
# ❌ Place Not Found: CTF ILLLINOIS
#
# Processing: EASTER SEALS JOLIET REGION INC, 212 BARNEY DR, (815) 725-2194
# ❌ Place Not Found: EASTER SEALS JOLIET REGION INC
#
# Processing: ENVISION UNLIMITED, 8 S MICHIGAN AVE SUITE 1700, (312) 346-6230
# ❌ Place Not Found: ENVISION UNLIMITED
#
# Processing: EPIC, 1913 W Townline Rd, (309) 691-3800
# ✅ Place Verified: EPIC
#
# Processing: ESPERANZA COMMUNITY SERVICES, 520 N MARSHFIELD AVE, (312) 243-6097
# ✅ Place Verified: ESPERANZA COMMUNITY SERVICES
#
# Processing: FAMILIES BUILDING DREAMS, 2970 MARIA AVE #211, (847) 272-2222
# ❌ Place Not Found: FAMILIES BUILDING DREAMS
#
# Processing: FAMILY ASSOCIATION PLUS, 15746 VINE, (708) 473-6420
# ❌ Place Not Found: FAMILY ASSOCIATION PLUS
#
# Processing: FERN LEAF ABA, LLC, 5739 W MARTINDALE LN,, (309) 253-1683
# ❌ Place Not Found: FERN LEAF ABA, LLC
#
# Processing: FOREST CITY BEHAVIOR AND DEVELOPMENT, 9510 St Clair Ave, (618) 277-4100
# ✅ Place Verified: FOREST CITY BEHAVIOR AND DEVELOPMENT
#
# Processing: FRAKES, JENNIFER L, Not Available, (217) 588-8638
# ❌ Place Not Found: FRAKES, JENNIFER L
#
# Processing: FUNDERBURG, DYNATA, Not Available, (708) 647-6426
# ❌ Place Not Found: FUNDERBURG, DYNATA
#
# Processing: GAODE, ERIC, Not Available, (847) 890-1157
# ❌ Place Not Found: GAODE, ERIC
#
# Processing: GATEWAY SERVICES, INC., 406 S GOSSE BLVD, (815) 875-4548
# ❌ Place Not Found: GATEWAY SERVICES, INC.
#
# Processing: GLENKIRK, 3504 COMMERCIAL AVE., (847) 272-5111
# ✅ Place Verified: GLENKIRK
#
# Processing: HAWK PSYCHOLOGICAL SERVICES, 7660 Gross Point Road, (847) 967-1800
# ❌ Place Not Found: HAWK PSYCHOLOGICAL SERVICES
#
# Processing: HELPING HAND CENTER, 9649 W 55TH ST, (708) 352-3580
# ✅ Place Verified: HELPING HAND CENTER
#
# Processing: Herrera, Alexis, Not Available, (847)772-0436
# ❌ Place Not Found: Herrera, Alexis
#
# Processing: HUMAN SUPPORT SERVICES, 988 N. Illinois Route 3, PO BOX 146, (618) 939-4444
# ❌ Place Not Found: HUMAN SUPPORT SERVICES
#
# Processing: ILLINOIS MENTOR COMMUNITY SERVICES INC, 18440 Thompson Court Suite 104, (815) 464-3239
# ❌ Place Not Found: ILLINOIS MENTOR COMMUNITY SERVICES INC
#
# Processing: INDIVIDUAL ADVOCACY GROUP INC, 1289 WINDHAM PARKWAY, (630) 759-0201
# ❌ Place Not Found: INDIVIDUAL ADVOCACY GROUP INC
#
# Processing: INDIVIDUAL BEHAVIOR SUPPORT LLC, 1107 W Deyoung St, Suite 70, (314) 428-2328
# ❌ Place Not Found: INDIVIDUAL BEHAVIOR SUPPORT LLC
#
# Processing: INSTRUCTIONAL ABA CONSULTANTS inc, 1975 McDowell Road, #101, (331) 229-8839
# ❌ Place Not Found: INSTRUCTIONAL ABA CONSULTANTS inc
#
# Processing: JOSEPH REHABILITATION CENTER, 21209 SHANNON AVENUE, (708) 720-3315
# ✅ Place Verified: JOSEPH REHABILITATION CENTER
#
# Processing: KCCDD, INC., 2015 WINDISH DR, (309) 344-2600
# ❌ Place Not Found: KCCDD, INC.
#
# Processing: KESHET, 610 Academy Dr, (847) 205-1234
# ✅ Place Verified: KESHET
#
# Processing: KREIDER SERVICES INC., 500 ANCHOR RD P O BOX 366, (815) 288-6691
# ❌ Place Not Found: KREIDER SERVICES INC.
#
# Processing: KRYPTON, INC, 10 A and K Dr., (618) 524-8996
# ❌ Place Not Found: KRYPTON, INC
#
# Processing: KRYSZAK, KELSEY, Not Available, (708) 663-6964
# ❌ Place Not Found: KRYSZAK, KELSEY
#
# Processing: LEEDA SERVICES OF ILLINOIS INC, 7344 N. Western Avenue, (773) 274-9760
# ❌ Place Not Found: LEEDA SERVICES OF ILLINOIS INC
#
# Processing: LEWIS, JENNIFER, Not Available, (630) 479-8936
# ❌ Place Not Found: LEWIS, JENNIFER
#
# Processing: LifeSpeed Behavioral Support Services, LLC, 721 South Blvd, Suite 210, (312) 404-7225
# ❌ Place Not Found: LifeSpeed Behavioral Support Services, LLC
#
# Processing: LINCOLN SQUARE INC, 202 S MAIN ST, (618) 833-2063
# ❌ Place Not Found: LINCOLN SQUARE INC
#
# Processing: LITTLE CITY FOUNDATION, 1760 W ALGONQUIN RD, (847) 358-5510
# ✅ Place Verified: LITTLE CITY FOUNDATION
#
# Processing: LITTLE FRIENDS, INC, 27555 DIEHL, (630) 355-6533
# ❌ Place Not Found: LITTLE FRIENDS, INC
#
# Processing: LIVESAY, JIMMIE R, Not Available, (618) 614-4265
# ❌ Place Not Found: LIVESAY, JIMMIE R
#
# Processing: MAFTEI, NADIA CLAUDIA, Not Available, (773) 558-7953
# ❌ Place Not Found: MAFTEI, NADIA CLAUDIA
#
# Processing: MARCFIRST, 1606 HUNT DRIVE, (309) 451-8888
# ✅ Place Verified: MARCFIRST
#
# Processing: MCALLISTER ANALYTICS INC, 7836 N Nora Ave, (708) 915-0920
# ❌ Place Not Found: MCALLISTER ANALYTICS INC
#
# Processing: MISERICORDIA HOME, 6300 N RIDGE, (773) 973-6300
# ✅ Place Verified: MISERICORDIA HOME
#
# Processing: MOMENTUM BEHAVIOR SERVICES LLC, 1999 INDIANA AVE, (708) 227-0793
# ❌ Place Not Found: MOMENTUM BEHAVIOR SERVICES LLC
#
# Processing: MOSAIC OF ILLINOIS, 220 N LAFAYETTE ST, (309) 837-5506
# ❌ Place Not Found: MOSAIC OF ILLINOIS
#
# Processing: NELSON, SCOTT, 6036 NORTH WINCHESTER, (847) 626-4816
# ✅ Place Verified: NELSON, SCOTT
#
# Processing: NEW STAR INC, 1005 W END AVE, (708) 755-8030
# ✅ Place Verified: NEW STAR INC
#
# Processing: NORTHERN IL BEHAVIORAL SERVICES, 500 WEST SOUTH ST, (815) 266-4239
# ❌ Place Not Found: NORTHERN IL BEHAVIORAL SERVICES
#
# Processing: NORTHPOINTE RESOURCES INC, 3441 SHERIDAN RD, (847) 872-1700
# ❌ Place Not Found: NORTHPOINTE RESOURCES INC
#
# Processing: NU-CARE INC, 19150 S KEDZIE AVE, (708) 922-2111
# ❌ Place Not Found: NU-CARE INC
#
# Processing: ORCHARD VILLAGE, 7660 Gross Point Road, (847) 967-1800
# ✅ Place Verified: ORCHARD VILLAGE
#
# Processing: PARK LAWN SCHOOL and ACTIVITY, 10833 S LAPORTE AVE, (708) 425-3344
# ❌ Place Not Found: PARK LAWN SCHOOL and ACTIVITY
#
# Processing: PATHWAY SERVICES UNLIMITED, INC., 1905 WEST MORTON AVE, (217) 479-2300
# ❌ Place Not Found: PATHWAY SERVICES UNLIMITED, INC.
#
# Processing: PATHWAYS THERAPEUTIC SERVICES INC, 15255 S 94TH AVE STE 500 PO BOX 1006, (312) 342-0631
# ❌ Place Not Found: PATHWAYS THERAPEUTIC SERVICES INC
#
# Processing: PRECISION ABA LLC, 2970 MARIA AVE #211, (847) 272-2222
# ❌ Place Not Found: PRECISION ABA LLC
#
# Processing: PREMIERCARE CONSULTING LLC, 1811 High Grove Lane, Suite 139, 1st Floor, (630) 579-4325
# ❌ Place Not Found: PREMIERCARE CONSULTING LLC
#
# Processing: PROGRESSIVE BEHAVIOR SOLUTIONS, 4109 FLORENCE WAY, (773) 780-1448
# ❌ Place Not Found: PROGRESSIVE BEHAVIOR SOLUTIONS
#
# Processing: R and J ENTERPRISES COUNTRY LIVING INC, 221 EAST AVE, (618) 833-7418
# ✅ Place Verified: R and J ENTERPRISES COUNTRY LIVING INC
#
# Processing: RANGE OF MOTION INC, 135 E. St. Charles Road, Ste G, (630) 871-8696
# ❌ Place Not Found: RANGE OF MOTION INC
#
# Processing: RAY GRAHAM ASSOCIATION, 901 Warrenville Road, Suite 500, 630-620 2222
# ✅ Place Verified: RAY GRAHAM ASSOCIATION
#
# Processing: RICKETTS, TANEA, Not Available, (618) 339-1063
# ❌ Place Not Found: RICKETTS, TANEA
#
# Processing: ROYAL LIVING CENTER, INC, 200 SOUTH 9TH, (618) 588-7295
# ❌ Place Not Found: ROYAL LIVING CENTER, INC
#
# Processing: SAENZ, ABRAHAM, Not Available, (312) 451-4814
# ❌ Place Not Found: SAENZ, ABRAHAM
#
# Processing: SALHA, LORI, Not Available, (708) 351-2676
# ❌ Place Not Found: SALHA, LORI
#
# Processing: SEARCH DEVELOPMENTAL CENTER, 1925 N CLYBOURN AVE STE 200, (773) 305-5000
# ❌ Place Not Found: SEARCH DEVELOPMENTAL CENTER
#
# Processing: SERTOMA CENTRE INC, 4343 W 123RD ST, (708) 371-9700
# ❌ Place Not Found: SERTOMA CENTRE INC
#
# Processing: SHORE COMMUNITY SERVICES, INC, 8350 LARAMIE AVE, (847) 982-2030
# ❌ Place Not Found: SHORE COMMUNITY SERVICES, INC
#
# Processing: Smith, Verma, Not Available, (708) 510-7122
# ❌ Place Not Found: Smith, Verma
#
# Processing: SOLID GROUND BEHAVIORAL SRVCS, 11940 S SPRINGFIELD AVE, (708) 969-4109
# ❌ Place Not Found: SOLID GROUND BEHAVIORAL SRVCS
#
# Processing: SPARC, 232 BRUNS LANE, (217) 793-2100
# ✅ Place Verified: SPARC
#
# Processing: SPECIALIZED TRAINING FOR ADULT REHABILITATION, 20 North 13st Street, P.O. BOX 938, (618) 687-2378
# ❌ Place Not Found: SPECIALIZED TRAINING FOR ADULT REHABILITATION
#
# Processing: SPRINGHEALTH BEHAVIOR HEALTH OF IL, LLC, 18440 Thompson Court Suite 104, (815) 464-3239
# ❌ Place Not Found: SPRINGHEALTH BEHAVIOR HEALTH OF IL, LLC
#
# Processing: ST COLETTA'S OF ILLINOIS, 18350 CROSSING DR, (708) 342-5200
# ❌ Place Not Found: ST COLETTA'S OF ILLINOIS
#
# Processing: STATE OF MIND MENTAL HEALTH AND COUNSELING SERVICES, 17911 LOS ANGELES AVE, (773) 807-2144
# ✅ Place Verified: STATE OF MIND MENTAL HEALTH AND COUNSELING SERVICES
#
# Processing: STEINBERG BEHAVIOR SOLUTIONS, 3109 W NORTH SHORE AVE, (847) 676-5398
# ✅ Place Verified: STEINBERG BEHAVIOR SOLUTIONS
#
# Processing: STREATOR UNLIMITED INC, 305 N Sterling St PO Box 706, (815) 673-5574
# ❌ Place Not Found: STREATOR UNLIMITED INC
#
# Processing: STUBNAR, HOLLY, Not Available, (618) 201-1146
# ❌ Place Not Found: STUBNAR, HOLLY
#
# Processing: SUPPORT SYSTEMS AND SERVICES INC, 9510 St Clair Ave, (618) 277-4100
# ❌ Place Not Found: SUPPORT SYSTEMS AND SERVICES INC
#
# Processing: Supporting Community Independence, LLC, 1 Polo Grounds Ct, (618) 806-4344
# ✅ Place Verified: Supporting Community Independence, LLC
#
# Processing: TASH INC, PO Box 338 - 1303 N 7th Street, (618) 867-3881
# ❌ Place Not Found: TASH INC
#
# Processing: THE ARC OF THE QUAD CITIES AREA, 4016 9th St, (309) 786-6474
# ✅ Place Verified: THE ARC OF THE QUAD CITIES AREA
#
# Processing: TRADE INDUSTRIES, 1020 E. Randolph St P.O. Box 70,, (618) 643-4321
# ❌ Place Not Found: TRADE INDUSTRIES
#
# Processing: TRANSITIONS OF WESTERN ILLINOIS, 4409 Maine St, (217) 223-0413
# ❌ Place Not Found: TRANSITIONS OF WESTERN ILLINOIS
#
# Processing: TRINITY SERVICES INC, 301 Veterans Parkway, (815) 485-6197
# ✅ Place Verified: TRINITY SERVICES INC
#
# Processing: TWEEDY, RICHARD, Not Available, (618) 697-2238
# ❌ Place Not Found: TWEEDY, RICHARD
#
# Processing: UNITED CEREBRAL PALSY SEGUIN OF GREATER CHICAGO, 3100 South Central Ave, (708) 863-3803
# ✅ Place Verified: UNITED CEREBRAL PALSY SEGUIN OF GREATER CHICAGO
#
# Processing: WARREN ACHIEVEMENT CENTER, 1220 East 2nd Ave, (309) 734-3131
# ❌ Place Not Found: WARREN ACHIEVEMENT CENTER
#
# Processing: WILLIAM M BEDELL ACHIEVEMENT, P O BOX 349 - 400 S Main, (618) 251-2175
# ❌ Place Not Found: WILLIAM M BEDELL ACHIEVEMENT
#
# Processing: WINBUSH, KELLYE M, Not Available, (404) 849-8248
# ❌ Place Not Found: WINBUSH, KELLYE M
#
# Verification completed. Results saved to 'Verified_Illinois_Illinois_Behavior_Intervention_Providers.csv'.

# %%
# Illinois_CLF_Providers
clf_df = dfs[3][dfs[3]['State'] == 'IL']
clf_verified_providers = []

for index, row in clf_df.iterrows():
    # Extract provider details
    provider_name = row['Provider Name']
    provider_address = row['Street Address']
    provider_phone_number = row['Phone Number']
    city = row['City']
    state = row['State']

    print(f"\nProcessing: {provider_name}, {provider_address}, {provider_phone_number}")

    # Verify provider using Google API and fallback to Yelp API
    exists, data = verify_provider(provider_name, provider_address, provider_phone_number, city, state)

    if exists:
        clf_verified_providers.append({
            'Provider Name': provider_name,
            'Address': provider_address,
            'Phone Number': provider_phone_number,
            'Verified': exists,
            'Matched Data': data  # Store the matched result for debugging
        })
        print(f"✅ Place Verified: {provider_name}")
    else:
        print(f"❌ Place Not Found: {provider_name}")

    # Sleep to respect rate limits
    time.sleep(1)

# Convert results to DataFrame and save to CSV
verified_df = pd.DataFrame(clf_verified_providers)
verified_df.to_csv('verified providers/Verified_CLF_Providers.csv', index=False)

print("\nVerification completed. Results saved to 'Verified_CLF_Providers.csv'.")
# Out:
# Processing: AVENUES TO INDEPENDENCE, 515 Busse Hwy, 847-292 0870
# ❌ Place Not Found: AVENUES TO INDEPENDENCE
#
# Processing: COMMUNITY WORKSHOP & TRAINING, 3215 N UNIVERSITY, 309-686 3300
# ❌ Place Not Found: COMMUNITY WORKSHOP & TRAINING
#
# Processing: CROSSPOINT HUMAN SERVICES, 210 AVENUE C, 217-442 3200
# ❌ Place Not Found: CROSSPOINT HUMAN SERVICES
#
# Processing: GLENKIRK, 3504 COMMERCIAL AVE., 847-272 5111
# ✅ Place Verified: GLENKIRK
#
# Processing: LAMBS FARM, 14245 W Rockland Rd, 847-362 4636
# ✅ Place Verified: LAMBS FARM
#
# Processing: LITTLE CITY FOUNDATION, 1760 W Algonquin Rd, 847-358-5510
# ✅ Place Verified: LITTLE CITY FOUNDATION
#
# Processing: OPPORTUNITY HOUSE INC, 357 N. California St, 815-895 5108
# ❌ Place Not Found: OPPORTUNITY HOUSE INC
#
# Processing: SHORE COMMUNITY SERVICES, INC, 8350 LARAMIE AVE, 847-982 2030
# ❌ Place Not Found: SHORE COMMUNITY SERVICES, INC
#
# Processing: ST MARY OF PROVIDENCE SCHOOL, 4200 N Austin, 773-545 8300
# ✅ Place Verified: ST MARY OF PROVIDENCE SCHOOL
#
# Verification completed. Results saved to 'Verified_CLF_Providers.csv'.
